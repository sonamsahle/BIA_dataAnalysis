# %% [markdown]
# # ########covid-19 small dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/HP PC/Downloads/4. covid_19_data.csv')

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
# use  to count funcations is check the null value is not(not null)
df.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
df.isnull().head(20)
# Out:
#      Date  State  Region  Confirmed  Deaths  Recovered
# 0   False   True   False      False   False      False
# 1   False   True   False      False   False      False
# 2   False   True   False      False   False      False
# 3   False   True   False      False   False      False
# 4   False   True   False      False   False      False
# 5   False   True   False      False   False      False
# 6   False   True   False      False   False      False
# 7   False   True   False      False   False      False
# 8   False   True   False      False   False      False
# 9   False   True   False      False   False      False
# 10  False   True   False      False   False      False
# 11  False   True   False      False   False      False
# 12  False   True   False      False   False      False
# 13  False   True   False      False   False      False
# 14  False   True   False      False   False      False
# 15  False   True   False      False   False      False
# ...

# %%
df.isnull().head(20).sum()
# Out:
# Date          0
# State        20
# Region        0
# Confirmed     0
# Deaths        0
# Recovered     0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
sns.heatmap(df.notnull())
plt.show()

# %% [markdown]
# # comfirmed,deaths and recovered cases in each region

# %% [markdown]
# # number of comfirmed deaths

# %% [markdown]
# 1.show the number of confirmed.deaths and recovered cases in each region.

# %%
df.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
df.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
for i in enumerate(df.columns):
    print(i)
# Out:
# (0, 'Date')
# (1, 'State')
# (2, 'Region')
# (3, 'Confirmed')
# (4, 'Deaths')
# (5, 'Recovered')

# %%
df=df.iloc[:,[0,1,2,3,4,5]]

# %%
df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
df.groupby('Region')['Confirmed','Recovered'].sum()
# Out:
# C:\Users\HP PC\AppData\Local\Temp\ipykernel_4068\106003874.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Region')['Confirmed','Recovered'].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# remove all the records where comfirmed cases is grater than 10.

# %%
df.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
df[~(df.Confirmed<10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
df=df[~(df.Confirmed<10)]

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# 3.in which region, maximum number of confirmed cases were recoded.

# %%
df.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# 4.in which Region, minimum number of deaths cases were recorded.

# %%
df.head(1)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252

# %%
df.groupby('Region').Deaths .sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US             60967
# Italy          27682
# UK             26165
# Spain          24275
# France         24121
# Belgium         7501
# Germany         6467
# Iran            5957
# Brazil          5513
# Netherlands     4727
# Name: Deaths, dtype: int64

# %% [markdown]
# 5. how many confirmed ,Deaths and recovered cases were reported from india till 29 april 2020.

# %%
df[df.Region=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
df[df.Region=='US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %%
df[df.Region=='Alabama']
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered]
# Index: []

# %%
df[df.Region=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
df[df.Region=='US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %% [markdown]
# 6.Sort the entire data wrt no.of confirmed cases in ascending order.

# %%
df.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
df.sort_values(by=['Confirmed'],ascending=False)
# Out:
#           Date     State      Region  Confirmed  Deaths  Recovered
# 265  4/29/2020  New York          US     299691   23477          0
# 153  4/29/2020       NaN       Spain     236899   24275     132929
# 80   4/29/2020       NaN       Italy     203591   27682      71252
# 168  4/29/2020       NaN          UK     165221   26097          0
# 57   4/29/2020       NaN      France     165093   24087      48228
# ..         ...       ...         ...        ...     ...        ...
# 144  4/29/2020       NaN  Seychelles         11       0          6
# 27   4/29/2020       NaN     Burundi         11       1          4
# 59   4/29/2020       NaN      Gambia         10       1          8
# 156  4/29/2020       NaN    Suriname         10       1          8
# 70   4/29/2020       NaN    Holy See         10       0          2
#
# [304 rows x 6 columns]

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (130, 6)

# %%
df.head()
# Out:
#           Date    State          Region  Confirmed  Deaths  Recovered
# 181  4/29/2020  Alabama              US       6912     256          0
# 182  4/29/2020   Alaska              US        355       9          0
# 183  4/29/2020  Alberta          Canada       5165      87          0
# 185  4/29/2020    Anhui  Mainland China        991       6        985
# 186  4/29/2020  Arizona              US       7209     308          0

# %%
import matplotlib.pyplot as plt

plt.hist(df["Confirmed"])
plt.xlabel("Confirmed Cases")
plt.ylabel("Frequency")
plt.title("Histogram of Confirmed Cases")
plt.show()
